# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
data_act = pd.read_csv('../data_sql/actor.csv', encoding = 'utf-8', encoding_errors = 'ignore')
data_cat = pd.read_csv('../data_sql/category.csv', encoding = 'utf-8', encoding_errors = 'ignore')
data_film = pd.read_csv('../data_sql/film.csv', encoding = 'utf-8', encoding_errors = 'ignore')
data_inv = pd.read_csv('../data_sql/inventory.csv', encoding = 'utf-8', encoding_errors = 'ignore')
data_lan = pd.read_csv('../data_sql/language.csv', encoding = 'utf-8', encoding_errors = 'ignore')
data_old = pd.read_csv('../data_sql/old_HDD.csv', encoding = 'utf-8', encoding_errors = 'ignore')
data_rent = pd.read_csv('../data_sql/rental.csv', encoding = 'utf-8', encoding_errors = 'ignore')

# %% [markdown]
# # Printeamos los DataFrame para visualizarlos

# %%
data_act.head()
# Out:
#    actor_id first_name     last_name          last_update
# 0         1   PENELOPE       GUINESS  2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG  2006-02-15 04:34:33
# 2         3         ED         CHASE  2006-02-15 04:34:33
# 3         4   JENNIFER         DAVIS  2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA  2006-02-15 04:34:33

# %%
data_cat.head()
# Out:
#    category_id       name          last_update
# 0            1     Action  2006-02-15 04:46:27
# 1            2  Animation  2006-02-15 04:46:27
# 2            3   Children  2006-02-15 04:46:27
# 3            4   Classics  2006-02-15 04:46:27
# 4            5     Comedy  2006-02-15 04:46:27

# %%
data_film.head()
# Out:
#    film_id             title
# 0        1  ACADEMY DINOSAUR  \
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description  release_year
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006  \
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
#
#    language_id  original_language_id  rental_duration  rental_rate  length
# 0            1                   NaN                6         0.99      86  \
# 1            1                   NaN                3         4.99      48
# 2            1                   NaN                7         2.99      50
# 3            1                   NaN                5         2.99     117
# ...

# %%
data_inv.head()
# Out:
#    inventory_id  film_id  store_id          last_update
# 0             1        1         1  2006-02-15 05:09:17
# 1             2        1         1  2006-02-15 05:09:17
# 2             3        1         1  2006-02-15 05:09:17
# 3             4        1         1  2006-02-15 05:09:17
# 4             5        1         2  2006-02-15 05:09:17

# %%
data_lan.head()
# Out:
#    language_id      name          last_update
# 0            1   English  2006-02-15 05:02:19
# 1            2   Italian  2006-02-15 05:02:19
# 2            3  Japanese  2006-02-15 05:02:19
# 3            4  Mandarin  2006-02-15 05:02:19
# 4            5    French  2006-02-15 05:02:19

# %%
data_old.head()
# Out:
#   first_name last_name                  title  release_year  category_id
# 0   PENELOPE   GUINESS       ACADEMY DINOSAUR          2006            6
# 1   PENELOPE   GUINESS   ANACONDA CONFESSIONS          2006            2
# 2   PENELOPE   GUINESS            ANGELS LIFE          2006           13
# 3   PENELOPE   GUINESS  BULWORTH COMMANDMENTS          2006           10
# 4   PENELOPE   GUINESS          CHEAPER CLYDE          2006           14

# %%
data_rent.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id
# 0          1  2005-05-24 22:53:30           367          130  \
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
#
#            return_date  staff_id          last_update
# 0  2005-05-26 22:04:30         1  2006-02-15 21:30:53
# 1  2005-05-28 19:40:33         1  2006-02-15 21:30:53
# 2  2005-06-01 22:12:39         1  2006-02-15 21:30:53
# 3  2005-06-03 01:43:41         2  2006-02-15 21:30:53
# 4  2005-06-02 04:33:21         1  2006-02-15 21:30:53

# %% [markdown]
# # Verificamos si hay duplicados en alguno

# %%
data_act.drop_duplicates().shape == data_act.shape
# Out:
# True

# %%
data_cat.drop_duplicates().shape == data_cat.shape
# Out:
# True

# %%
data_film.drop_duplicates().shape == data_film.shape
# Out:
# True

# %%
data_inv.drop_duplicates().shape == data_inv.shape
# Out:
# True

# %%
data_lan.drop_duplicates().shape == data_lan.shape
# Out:
# True

# %%
data_old.drop_duplicates().shape == data_old.shape
# Out:
# True

# %%
data_rent.drop_duplicates().shape == data_rent.shape
# Out:
# True

# %% [markdown]
# # Empezamos a modificar algunos detalles de cada DataFrame

# %% [markdown]
# ### DataFrame 'Actors'

# %%
data_act.drop('last_update', axis = 1, inplace = True)

# %%
data_act.head()
# Out:
#    actor_id first_name     last_name
# 0         1   PENELOPE       GUINESS
# 1         2       NICK      WAHLBERG
# 2         3         ED         CHASE
# 3         4   JENNIFER         DAVIS
# 4         5     JOHNNY  LOLLOBRIGIDA

# %% [markdown]
# ### DataFrame 'Category'

# %%
data_cat.drop('last_update', axis = 1, inplace = True)

# %%
data_cat.head()
# Out:
#    category_id       name
# 0            1     Action
# 1            2  Animation
# 2            3   Children
# 3            4   Classics
# 4            5     Comedy

# %% [markdown]
# ### DataFrame 'Film'

# %%
data_film.drop('last_update', axis = 1, inplace = True)
data_film.drop('original_language_id', axis = 1, inplace = True)
data_film['release_year'] = ''
data_film.rename({'language_id': 'language'}, axis=1, inplace=True)
data_film.language = 'English'

# %%
data_film.head()
# Out:
#    film_id             title
# 0        1  ACADEMY DINOSAUR  \
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description release_year language
# 0  A Epic Drama of a Feminist And a Mad Scientist...               English  \
# 1  A Astounding Epistle of a Database Administrat...               English
# 2  A Astounding Reflection of a Lumberjack And a ...               English
# 3  A Fanciful Documentary of a Frisbee And a Lumb...               English
# 4  A Fast-Paced Documentary of a Pastry Chef And ...               English
#
#    rental_duration  rental_rate  length  replacement_cost rating
# 0                6         0.99      86             20.99     PG  \
# 1                3         4.99      48             12.99      G
# 2                7         2.99      50             18.99  NC-17
# 3                5         2.99     117             26.99      G
# ...

# %% [markdown]
# ### DataFrame 'Inventory'

# %%
data_inv.drop('last_update', axis = 1, inplace = True)

# %%
data_inv.head()
# Out:
#    inventory_id  film_id  store_id
# 0             1        1         1
# 1             2        1         1
# 2             3        1         1
# 3             4        1         1
# 4             5        1         2

# %% [markdown]
# ### DataFrame 'Language'

# %%
data_lan.drop('last_update', axis = 1, inplace = True)

# %%
data_lan.head()
# Out:
#    language_id      name
# 0            1   English
# 1            2   Italian
# 2            3  Japanese
# 3            4  Mandarin
# 4            5    French

# %% [markdown]
# ### DataFrame 'Old HDD'

# %%
data_old.drop('release_year', axis = 1, inplace = True)

# %%
data_old.head()
# Out:
#   first_name last_name                  title  category_id
# 0   PENELOPE   GUINESS       ACADEMY DINOSAUR            6
# 1   PENELOPE   GUINESS   ANACONDA CONFESSIONS            2
# 2   PENELOPE   GUINESS            ANGELS LIFE           13
# 3   PENELOPE   GUINESS  BULWORTH COMMANDMENTS           10
# 4   PENELOPE   GUINESS          CHEAPER CLYDE           14

# %% [markdown]
# ### DataFrame 'Rental'

# %%
data_rent.drop('last_update', axis = 1, inplace = True)

# %%
data_rent.head()
# Out:
#    rental_id          rental_date  inventory_id  customer_id
# 0          1  2005-05-24 22:53:30           367          130  \
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
#
#            return_date  staff_id
# 0  2005-05-26 22:04:30         1
# 1  2005-05-28 19:40:33         1
# 2  2005-06-01 22:12:39         1
# 3  2005-06-03 01:43:41         2
# 4  2005-06-02 04:33:21         1

# %% [markdown]
# # Ultimos detalles influenciados hacia la posterior construccion del DataBase en SQL

# %%
data_film['actors'] = ''

def actors(movie): 
    act = []
    for i in data_old.index:
        if data_old.title[i] == movie: 
            name = data_old.first_name[i] + ' ' + data_old.last_name[i]
            act.append(name)
    return ', '.join(act)

for i in data_film.index:
    data_film['actors'][i] = actors(data_film.title[i])

# %%
data_film['category'] = ''

def category(movie):
    categor = ''
    for i in data_old.index:
        if data_old.title[i] == movie:
            categor = data_cat[data_cat.category_id == data_old.category_id[i]].name.iloc[0]
            return categor

for i in data_film.index:
    data_film['category'][i] = category(data_film.title[i])

data_film.category.fillna('', inplace=True)

# %%
data_film.head()
# Out:
#    film_id             title
# 0        1  ACADEMY DINOSAUR  \
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
#
#                                          description release_year language
# 0  A Epic Drama of a Feminist And a Mad Scientist...               English  \
# 1  A Astounding Epistle of a Database Administrat...               English
# 2  A Astounding Reflection of a Lumberjack And a ...               English
# 3  A Fanciful Documentary of a Frisbee And a Lumb...               English
# 4  A Fast-Paced Documentary of a Pastry Chef And ...               English
#
#    rental_duration  rental_rate  length  replacement_cost rating
# 0                6         0.99      86             20.99     PG  \
# 1                3         4.99      48             12.99      G
# 2                7         2.99      50             18.99  NC-17
# 3                5         2.99     117             26.99      G
# ...

# %%
data_client = pd.DataFrame({'client_id': range(1, 1001)})  # creamos la tabal de 'client' desde aqui, pporque da problemas al hacerlo desde sql
data_client['name'] = ''
data_client['last_name'] = ''
data_client['address'] = ''
data_client['phone_num'] = ''
data_client['email'] = ''

# %%
data_client.head()
# Out:
#    client_id name last_name address phone_num email
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5

# %% [markdown]
# # Exportación de archivos

# %%
data_act = data_act.to_csv('../data_sql_modif/data_act.csv', index = False)
data_cat = data_cat.to_csv('../data_sql_modif/data_cat.csv', index = False)
data_film = data_film.to_csv('../data_sql_modif/data_film.csv', index = False)
data_inv = data_inv.to_csv('../data_sql_modif/data_inv.csv', index = False)
data_lan = data_lan.to_csv('../data_sql_modif/data_lan.csv', index = False)
data_old = data_old.to_csv('../data_sql_modif/data_old.csv', index = False)
data_rent = data_rent.to_csv('../data_sql_modif/data_rent.csv', index = False)
data_client = data_client.to_csv('../data_sql_modif/data_client.csv', index = False)
